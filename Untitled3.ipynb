# %%
x = True
print(type(x))
# Out:
# <class 'bool'>

# %%
print(bool("abc"))
# Out:
# True

# %%
print(bool(0))
# Out:
# False

# %%
while 2>1:
    print('d')
# Out:
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# d
# ...
